# %%
# !git clone https://github.com/eriklindernoren/PyTorch-YOLOv3
# Out:
# Cloning into 'PyTorch-YOLOv3'...
# remote: Enumerating objects: 1924, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 1924 (delta 46), reused 65 (delta 32), pack-reused 1834
# Receiving objects: 100% (1924/1924), 16.63 MiB | 34.76 MiB/s, done.
# Resolving deltas: 100% (1141/1141), done.

# %%
cd PyTorch-YOLOv3/
# Out:
# /content/PyTorch-YOLOv3

# %%
# !pip freeze
# Out:
# absl-py==1.3.0
# aeppl==0.0.33
# aesara==2.7.9
# aiohttp==3.8.3
# aiosignal==1.3.1
# alabaster==0.7.12
# albumentations==1.2.1
# altair==4.2.0
# appdirs==1.4.4
# arviz==0.12.1
# astor==0.8.1
# astropy==4.3.1
# astunparse==1.6.3
# async-timeout==4.0.2
# asynctest==0.13.0
# atari-py==0.2.9
# atomicwrites==1.4.1
# attrs==22.1.0
# audioread==3.0.0
# autograd==1.5
# Babel==2.11.0
# backcall==0.2.0
# beautifulsoup4==4.6.3
# bleach==5.0.1
# blis==0.7.9
# bokeh==2.3.3
# branca==0.6.0
# bs4==0.0.1
# CacheControl==0.12.11
# cached-property==1.5.2
# cachetools==5.2.0
# catalogue==2.0.8
# certifi==2022.9.24
# cffi==1.15.1
# cftime==1.6.2
# chardet==3.0.4
# charset-normalizer==2.1.1
# click==7.1.2
# clikit==0.6.2
# cloudpickle==1.5.0
# cmake==3.22.6
# cmdstanpy==1.0.8
# colorcet==3.0.1
# colorlover==0.3.0
# community==1.0.0b1
# confection==0.0.3
# cons==0.4.5
# contextlib2==0.5.5
# convertdate==2.4.0
# crashtest==0.3.1
# crcmod==1.7
# cufflinks==0.17.3
# cvxopt==1.3.0
# cvxpy==1.2.2
# cycler==0.11.0
# cymem==2.0.7
# Cython==0.29.32
# daft==0.0.4
# dask==2022.2.0
# datascience==0.17.5
# db-dtypes==1.0.4
# debugpy==1.0.0
# decorator==4.4.2
# defusedxml==0.7.1
# descartes==1.1.0
# dill==0.3.6
# distributed==2022.2.0
# dlib==19.24.0
# dm-tree==0.1.7
# dnspython==2.2.1
# docutils==0.17.1
# dopamine-rl==1.0.5
# earthengine-api==0.1.332
# easydict==1.10
# ecos==2.0.10
# editdistance==0.5.3
# en-core-web-sm @ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl
# entrypoints==0.4
# ephem==4.1.3
# et-xmlfile==1.1.0
# etils==0.9.0
# etuples==0.3.8
# fa2==0.3.5
# fastai==2.7.10
# fastcore==1.5.27
# fastdownload==0.0.7
# fastdtw==0.3.4
# fastjsonschema==2.16.2
# fastprogress==1.0.3
# fastrlock==0.8.1
# feather-format==0.4.1
# filelock==3.8.0
# firebase-admin==5.3.0
# fix-yahoo-finance==0.0.22
# Flask==1.1.4
# flatbuffers==1.12
# folium==0.12.1.post1
# frozenlist==1.3.3
# fsspec==2022.11.0
# future==0.16.0
# gast==0.4.0
# GDAL==2.2.2
# gdown==4.4.0
# gensim==3.6.0
# geographiclib==1.52
# geopy==1.17.0
# gin-config==0.5.0
# glob2==0.7
# google==2.0.3
# google-api-core==2.8.2
# google-api-python-client==1.12.11
# google-auth==2.14.1
# google-auth-httplib2==0.0.4
# google-auth-oauthlib==0.4.6
# google-cloud-bigquery==3.3.6
# google-cloud-bigquery-storage==2.16.2
# google-cloud-core==2.3.2
# google-cloud-datastore==2.9.0
# google-cloud-firestore==2.7.2
# google-cloud-language==2.6.1
# google-cloud-storage==2.5.0
# google-cloud-translate==3.8.4
# google-colab @ file:///colabtools/dist/google-colab-1.0.0.tar.gz
# google-crc32c==1.5.0
# google-pasta==0.2.0
# google-resumable-media==2.4.0
# googleapis-common-protos==1.57.0
# googledrivedownloader==0.4
# graphviz==0.10.1
# greenlet==2.0.1
# grpcio==1.50.0
# grpcio-status==1.48.2
# gspread==3.4.2
# gspread-dataframe==3.0.8
# gym==0.25.2
# gym-notices==0.0.8
# h5py==3.1.0
# HeapDict==1.0.1
# hijri-converter==2.2.4
# holidays==0.17
# holoviews==1.14.9
# html5lib==1.0.1
# httpimport==0.5.18
# httplib2==0.17.4
# httpstan==4.6.1
# humanize==0.5.1
# hyperopt==0.1.2
# idna==2.10
# imageio==2.9.0
# imagesize==1.4.1
# imbalanced-learn==0.8.1
# imblearn==0.0
# imgaug==0.4.0
# importlib-metadata==4.13.0
# importlib-resources==5.10.0
# imutils==0.5.4
# inflect==2.1.0
# intel-openmp==2022.2.1
# intervaltree==2.1.0
# ipykernel==5.3.4
# ipython==7.9.0
# ipython-genutils==0.2.0
# ipython-sql==0.3.9
# ipywidgets==7.7.1
# itsdangerous==1.1.0
# jax==0.3.25
# jaxlib @ https://storage.googleapis.com/jax-releases/cuda11/jaxlib-0.3.25+cuda11.cudnn805-cp37-cp37m-manylinux2014_x86_64.whl
# jieba==0.42.1
# Jinja2==2.11.3
# joblib==1.2.0
# jpeg4py==0.1.4
# jsonschema==4.3.3
# jupyter-client==6.1.12
# jupyter-console==6.1.0
# jupyter-core==4.11.2
# jupyterlab-widgets==3.0.3
# kaggle==1.5.12
# kapre==0.3.7
# keras==2.9.0
# Keras-Preprocessing==1.1.2
# keras-vis==0.4.1
# kiwisolver==1.4.4
# korean-lunar-calendar==0.3.1
# langcodes==3.3.0
# libclang==14.0.6
# librosa==0.8.1
# lightgbm==2.2.3
# llvmlite==0.39.1
# lmdb==0.99
# locket==1.0.0
# logical-unification==0.4.5
# LunarCalendar==0.0.9
# lxml==4.9.1
# Markdown==3.4.1
# MarkupSafe==2.0.1
# marshmallow==3.19.0
# matplotlib==3.2.2
# matplotlib-venn==0.11.7
# miniKanren==1.0.3
# missingno==0.5.1
# mistune==0.8.4
# mizani==0.7.3
# mkl==2019.0
# mlxtend==0.14.0
# more-itertools==9.0.0
# moviepy==0.2.3.5
# mpmath==1.2.1
# msgpack==1.0.4
# multidict==6.0.2
# multipledispatch==0.6.0
# multitasking==0.0.11
# murmurhash==1.0.9
# music21==5.5.0
# natsort==5.5.0
# nbconvert==5.6.1
# nbformat==5.7.0
# netCDF4==1.6.2
# networkx==2.6.3
# nibabel==3.0.2
# nltk==3.7
# notebook==5.7.16
# numba==0.56.4
# numexpr==2.8.4
# numpy==1.21.6
# oauth2client==4.1.3
# oauthlib==3.2.2
# okgrade==0.4.3
# opencv-contrib-python==4.6.0.66
# opencv-python==4.6.0.66
# opencv-python-headless==4.6.0.66
# openpyxl==3.0.10
# opt-einsum==3.3.0
# osqp==0.6.2.post0
# packaging==21.3
# palettable==3.3.0
# pandas==1.3.5
# pandas-datareader==0.9.0
# pandas-gbq==0.17.9
# pandas-profiling==1.4.1
# pandocfilters==1.5.0
# panel==0.12.1
# param==1.12.2
# parso==0.8.3
# partd==1.3.0
# pastel==0.2.1
# pathlib==1.0.1
# pathy==0.8.1
# patsy==0.5.3
# pep517==0.13.0
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==7.1.2
# pip-tools==6.2.0
# plotly==5.5.0
# plotnine==0.8.0
# pluggy==0.7.1
# pooch==1.6.0
# portpicker==1.3.9
# prefetch-generator==1.0.1
# preshed==3.0.8
# prettytable==3.5.0
# progressbar2==3.38.0
# prometheus-client==0.15.0
# promise==2.3
# prompt-toolkit==2.0.10
# prophet==1.1.1
# proto-plus==1.22.1
# protobuf==3.19.6
# psutil==5.4.8
# psycopg2==2.9.5
# ptyprocess==0.7.0
# py==1.11.0
# pyarrow==9.0.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycocotools==2.0.6
# pycparser==2.21
# pyct==0.4.8
# pydantic==1.10.2
# pydata-google-auth==1.4.0
# pydot==1.3.0
# pydot-ng==2.0.0
# pydotplus==2.0.2
# PyDrive==1.3.1
# pyemd==0.5.1
# pyerfa==2.0.0.1
# Pygments==2.6.1
# pygobject==3.26.1
# pylev==1.4.0
# pymc==4.1.4
# PyMeeus==0.5.11
# pymongo==4.3.3
# pymystem3==0.2.0
# PyOpenGL==3.1.6
# pyparsing==3.0.9
# pyrsistent==0.19.2
# pysimdjson==3.2.0
# pysndfile==1.3.8
# PySocks==1.7.1
# pystan==3.3.0
# pytest==3.6.4
# python-apt==0.0.0
# python-dateutil==2.8.2
# python-louvain==0.16
# python-slugify==6.1.2
# python-utils==3.4.5
# pytz==2022.6
# pyviz-comms==2.2.1
# PyWavelets==1.3.0
# PyYAML==6.0
# pyzmq==23.2.1
# qdldl==0.1.5.post2
# qudida==0.0.4
# regex==2022.6.2
# requests==2.23.0
# requests-oauthlib==1.3.1
# resampy==0.4.2
# rpy2==3.5.5
# rsa==4.9
# scikit-image==0.18.3
# scikit-learn==1.0.2
# scipy==1.7.3
# screen-resolution-extra==0.0.0
# scs==3.2.2
# seaborn==0.11.2
# Send2Trash==1.8.0
# setuptools-git==1.2
# Shapely==1.8.5.post1
# six==1.15.0
# sklearn-pandas==1.8.0
# smart-open==5.2.1
# snowballstemmer==2.2.0
# sortedcontainers==2.4.0
# soundfile==0.11.0
# spacy==3.4.3
# spacy-legacy==3.0.10
# spacy-loggers==1.0.3
# Sphinx==1.8.6
# sphinxcontrib-serializinghtml==1.1.5
# sphinxcontrib-websupport==1.2.4
# SQLAlchemy==1.4.44
# sqlparse==0.4.3
# srsly==2.4.5
# statsmodels==0.12.2
# sympy==1.7.1
# tables==3.7.0
# tabulate==0.8.10
# tblib==1.7.0
# tenacity==8.1.0
# tensorboard==2.9.1
# tensorboard-data-server==0.6.1
# tensorboard-plugin-wit==1.8.1
# tensorflow==2.9.2
# tensorflow-datasets==4.6.0
# tensorflow-estimator==2.9.0
# tensorflow-gcs-config==2.9.1
# tensorflow-hub==0.12.0
# tensorflow-io-gcs-filesystem==0.27.0
# tensorflow-metadata==1.11.0
# tensorflow-probability==0.17.0
# termcolor==2.1.0
# terminado==0.13.3
# testpath==0.6.0
# text-unidecode==1.3
# textblob==0.15.3
# thinc==8.1.5
# threadpoolctl==3.1.0
# tifffile==2021.11.2
# toml==0.10.2
# tomli==2.0.1
# toolz==0.12.0
# torch @ https://download.pytorch.org/whl/cu113/torch-1.12.1%2Bcu113-cp37-cp37m-linux_x86_64.whl
# torchaudio @ https://download.pytorch.org/whl/cu113/torchaudio-0.12.1%2Bcu113-cp37-cp37m-linux_x86_64.whl
# torchsummary==1.5.1
# torchtext==0.13.1
# torchvision @ https://download.pytorch.org/whl/cu113/torchvision-0.13.1%2Bcu113-cp37-cp37m-linux_x86_64.whl
# tornado==6.0.4
# tqdm==4.64.1
# traitlets==5.1.1
# tweepy==3.10.0
# typeguard==2.7.1
# typer==0.7.0
# typing-extensions==4.1.1
# tzlocal==1.5.1
# uritemplate==3.0.1
# urllib3==1.24.3
# vega-datasets==0.9.0
# wasabi==0.10.1
# wcwidth==0.2.5
# webargs==8.2.0
# webencodings==0.5.1
# Werkzeug==1.0.1
# widgetsnbextension==3.6.1
# wordcloud==1.8.2.2
# wrapt==1.14.1
# xarray==0.20.2
# xarray-einstats==0.2.2
# xgboost==0.90
# xkit==0.0.0
# xlrd==1.1.0
# xlwt==1.3.0
# yarl==1.8.1
# yellowbrick==1.5
# zict==2.2.0
# zipp==3.10.0

# %%
# !pip freeze > requirements.txt

# %%
# !pip3 install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm@ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 2.7 MB/s
# Processing /colabtools/dist/google-colab-1.0.0.tar.gz
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/colabtools/dist/google-colab-1.0.0.tar.gz'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd weights/
# Out:
# /content/PyTorch-YOLOv3/weights

# %%
# !cat /content/PyTorch-YOLOv3/weights/download_weights.sh
# Out:
# #!/bin/bash
# # Download weights for vanilla YOLOv3
# wget -c "https://pjreddie.com/media/files/yolov3.weights" --header "Referer: pjreddie.com"
# # # Download weights for tiny YOLOv3
# wget -c "https://pjreddie.com/media/files/yolov3-tiny.weights" --header "Referer: pjreddie.com"
# # Download weights for backbone network
# wget -c "https://pjreddie.com/media/files/darknet53.conv.74" --header "Referer: pjreddie.com"

# %%
# !bash download_weights.sh
# Out:
# --2022-11-24 10:30:01--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  39.4MB/s    in 6.5s
#
# 2022-11-24 10:30:08 (36.2 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]
#
# --2022-11-24 10:30:08--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  25.8MB/s    in 1.3s
#
# 2022-11-24 10:30:09 (25.8 MB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]
#
# --2022-11-24 10:30:09--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  39.8MB/s    in 4.3s
#
# 2022-11-24 10:30:14 (35.6 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !pip3 install poetry --user
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting poetry
#   Downloading poetry-1.2.2-py3-none-any.whl (212 kB)
#      |████████████████████████████████| 212 kB 4.9 MB/s
# Collecting urllib3<2.0.0,>=1.26.0
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 37.0 MB/s
# Requirement already satisfied: importlib-metadata<5.0,>=4.4 in /usr/local/lib/python3.7/dist-packages (from poetry) (4.13.0)
# Collecting requests-toolbelt<0.10.0,>=0.9.1
#   Downloading requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.1 MB/s
# Collecting cleo<2.0.0,>=1.0.0a5
#   Downloading cleo-1.0.0a5-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 6.5 MB/s
# Requirement already satisfied: crashtest<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from poetry) (0.3.1)
# Collecting pkginfo<2.0,>=1.5
#   Downloading pkginfo-1.8.3-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: html5lib<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from poetry) (1.0.1)
# Collecting cachy<0.4.0,>=0.3.0
#   Downloading cachy-0.3.0-py2.py3-none-any.whl (20 kB)
# Collecting platformdirs<3.0.0,>=2.5.2
#   Downloading platformdirs-2.5.4-py3-none-any.whl (14 kB)
# Collecting virtualenv!=20.4.5,!=20.4.6,>=20.4.3
#   Downloading virtualenv-20.16.7-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 52.2 MB/s
# Requirement already satisfied: cachecontrol[filecache]<0.13.0,>=0.12.9 in /usr/local/lib/python3.7/dist-packages (from poetry) (0.12.11)
# Collecting dulwich<0.21.0,>=0.20.46
#   Downloading dulwich-0.20.50-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (498 kB)
#      |████████████████████████████████| 498 kB 62.7 MB/s
# Collecting tomlkit!=0.11.2,!=0.11.3,<1.0.0,>=0.11.1
#   Downloading tomlkit-0.11.6-py3-none-any.whl (35 kB)
# Collecting poetry-core==1.3.2
#   Downloading poetry_core-1.3.2-py3-none-any.whl (531 kB)
#      |████████████████████████████████| 531 kB 22.6 MB/s
# Requirement already satisfied: pexpect<5.0.0,>=4.7.0 in /usr/local/lib/python3.7/dist-packages (from poetry) (4.8.0)
# Collecting jsonschema<5.0.0,>=4.10.0
#   Downloading jsonschema-4.17.1-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 6.2 MB/s
# Collecting backports.cached-property<2.0.0,>=1.0.2
#   Downloading backports.cached_property-1.0.2-py3-none-any.whl (6.1 kB)
# Collecting poetry-plugin-export<2.0.0,>=1.1.2
#   Downloading poetry_plugin_export-1.2.0-py3-none-any.whl (10 kB)
# Collecting shellingham<2.0,>=1.5
#   Downloading shellingham-1.5.0-py2.py3-none-any.whl (9.3 kB)
# Collecting keyring>=21.2.0
#   Downloading keyring-23.11.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: packaging>=20.4 in /usr/local/lib/python3.7/dist-packages (from poetry) (21.3)
# Requirement already satisfied: requests<3.0,>=2.18 in /usr/local/lib/python3.7/dist-packages (from poetry) (2.23.0)
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from cachecontrol[filecache]<0.13.0,>=0.12.9->poetry) (1.0.4)
# Collecting lockfile>=0.9
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: pylev<2.0.0,>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from cleo<2.0.0,>=1.0.0a5->poetry) (1.4.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from html5lib<2.0,>=1.0->poetry) (0.5.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from html5lib<2.0,>=1.0->poetry) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5.0,>=4.4->poetry) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5.0,>=4.4->poetry) (4.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema<5.0.0,>=4.10.0->poetry) (0.19.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema<5.0.0,>=4.10.0->poetry) (22.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema<5.0.0,>=4.10.0->poetry) (5.10.0)
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 4.8 MB/s
# Collecting jaraco.classes
#   Downloading jaraco.classes-3.2.3-py3-none-any.whl (6.0 kB)
# Collecting SecretStorage>=3.2
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.4->poetry) (3.0.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect<5.0.0,>=4.7.0->poetry) (0.7.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.18->poetry) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.18->poetry) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.18->poetry) (2022.9.24)
# Collecting requests<3.0,>=2.18
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.2 MB/s
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.18->poetry) (2.1.1)
# Collecting cryptography>=2.0
#   Downloading cryptography-38.0.3-cp36-abi3-manylinux_2_24_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 39.0 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=21.2.0->poetry) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=21.2.0->poetry) (2.21)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 53.3 MB/s
# Requirement already satisfied: filelock<4,>=3.4.1 in /usr/local/lib/python3.7/dist-packages (from virtualenv!=20.4.5,!=20.4.6,>=20.4.3->poetry) (3.8.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from jaraco.classes->keyring>=21.2.0->poetry) (9.0.0)
# Installing collected packages: urllib3, requests, jeepney, cryptography, SecretStorage, poetry-core, platformdirs, pkgutil-resolve-name, lockfile, jaraco.classes, distlib, virtualenv, tomlkit, shellingham, requests-toolbelt, poetry-plugin-export, pkginfo, keyring, jsonschema, dulwich, cleo, cachy, backports.cached-property, poetry
#   WARNING: The script virtualenv is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pkginfo is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script keyring is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jsonschema is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script dulwich is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script poetry is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed SecretStorage-3.3.3 backports.cached-property-1.0.2 cachy-0.3.0 cleo-1.0.0a5 cryptography-38.0.3 distlib-0.3.6 dulwich-0.20.50 jaraco.classes-3.2.3 jeepney-0.8.0 jsonschema-4.17.1 keyring-23.11.0 lockfile-0.12.2 pkginfo-1.8.3 pkgutil-resolve-name-1.3.10 platformdirs-2.5.4 poetry-1.2.2 poetry-core-1.3.2 poetry-plugin-export-1.2.0 requests-2.28.1 requests-toolbelt-0.9.1 shellingham-1.5.0 tomlkit-0.11.6 urllib3-1.26.13 virtualenv-20.16.7

# %%
cd /content/PyTorch-YOLOv3/pytorchyolo/
# Out:
# /content/PyTorch-YOLOv3/pytorchyolo

# %%
# !pip3 install pytorchyolo --user
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorchyolo
#   Downloading PyTorchYolo-1.7.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 984 kB/s
# Requirement already satisfied: numpy<2.0.0,>=1.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorchyolo) (1.21.6)
# Requirement already satisfied: torchvision>=0.13.1 in /usr/local/lib/python3.7/dist-packages (from pytorchyolo) (0.13.1+cu113)
# Collecting tensorboard<3.0.0,>=2.10.0
#   Downloading tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 8.5 MB/s
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in /usr/local/lib/python3.7/dist-packages (from pytorchyolo) (4.64.1)
# Requirement already satisfied: torch<1.13.0,>=1.10.1 in /usr/local/lib/python3.7/dist-packages (from pytorchyolo) (1.12.1+cu113)
# Collecting matplotlib<4.0.0,>=3.3.3
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 37.5 MB/s
# Requirement already satisfied: imgaug<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from pytorchyolo) (0.4.0)
# Collecting Pillow<10.0.0,>=9.1.0
#   Downloading Pillow-9.3.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 43.5 MB/s
# Requirement already satisfied: torchsummary<2.0.0,>=1.5.1 in /usr/local/lib/python3.7/dist-packages (from pytorchyolo) (1.5.1)
# Collecting terminaltables<4.0.0,>=3.1.0
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from imgaug<0.5.0,>=0.4.0->pytorchyolo) (1.7.3)
# Requirement already satisfied: imageio in /usr/local/lib/python3.7/dist-packages (from imgaug<0.5.0,>=0.4.0->pytorchyolo) (2.9.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from imgaug<0.5.0,>=0.4.0->pytorchyolo) (4.6.0.66)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.7/dist-packages (from imgaug<0.5.0,>=0.4.0->pytorchyolo) (1.8.5.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from imgaug<0.5.0,>=0.4.0->pytorchyolo) (1.15.0)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.7/dist-packages (from imgaug<0.5.0,>=0.4.0->pytorchyolo) (0.18.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.3.3->pytorchyolo) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.3.3->pytorchyolo) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.3.3->pytorchyolo) (1.4.4)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 48.1 MB/s
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.3.3->pytorchyolo) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.3.3->pytorchyolo) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib<4.0.0,>=3.3.3->pytorchyolo) (4.1.1)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.14.2->imgaug<0.5.0,>=0.4.0->pytorchyolo) (2.6.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.14.2->imgaug<0.5.0,>=0.4.0->pytorchyolo) (2021.11.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.14.2->imgaug<0.5.0,>=0.4.0->pytorchyolo) (1.3.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (1.3.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (2.14.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (1.50.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (3.4.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (0.38.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /root/.local/lib/python3.7/site-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (1.8.1)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (3.19.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3.0.0,>=2.10.0->pytorchyolo) (57.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (0.4.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /root/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3.0.0,>=2.10.0->pytorchyolo) (3.2.2)
# Installing collected packages: Pillow, fonttools, matplotlib, terminaltables, tensorboard, pytorchyolo
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts yolo-detect, yolo-test and yolo-train are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.9.2 requires tensorboard<2.10,>=2.9, but you have tensorboard 2.11.0 which is incompatible.
# Successfully installed Pillow-9.3.0 fonttools-4.38.0 matplotlib-3.5.3 pytorchyolo-1.7.1 tensorboard-2.11.0 terminaltables-3.1.10

# %%
# !python3 ./pytorchyolo/detect.py
# Out:
# python3: can't open file './pytorchyolo/detect.py': [Errno 2] No such file or directory

# %%
cd /content/PyTorch-YOLOv3/
# Out:
# /content/PyTorch-YOLOv3

# %%
# !python3 ./pytorchyolo/detect.py
# Out:
# Environment information:
# System: Linux 5.10.133+
# Not using the poetry package
# Current Commit Hash: ae6800d
# Command line arguments: Namespace(batch_size=1, classes='data/coco.names', conf_thres=0.5, images='data/samples', img_size=416, model='config/yolov3.cfg', n_cpu=8, nms_thres=0.4, output='output', weights='weights/yolov3.weights')
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Detecting: 100% 9/9 [00:13<00:00,  1.54s/it]
# Image data/samples/dog.jpg:
# 	+ Label: bicycle | Confidence: 0.9929
# 	+ Label: dog | Confidence: 0.9924
# 	+ Label: truck | Confidence: 0.9401
# Image data/samples/eagle.jpg:
# 	+ Label: bird | Confidence: 0.9969
# Image data/samples/field.jpg:
# 	+ Label: person | Confidence: 0.9999
# 	+ Label: horse | Confidence: 0.9984
# 	+ Label: dog | Confidence: 0.9944
# Image data/samples/giraffe.jpg:
# 	+ Label: giraffe | Confidence: 0.9935
# 	+ Label: zebra | Confidence: 0.9653
# 	+ Label: giraffe | Confidence: 0.6276
# Image data/samples/herd_of_horses.jpg:
# 	+ Label: horse | Confidence: 0.9852
# 	+ Label: horse | Confidence: 0.9740
# 	+ Label: horse | Confidence: 0.9636
# 	+ Label: horse | Confidence: 0.8883
# Image data/samples/messi.jpg:
# 	+ Label: person | Confidence: 0.9974
# 	+ Label: person | Confidence: 0.9954
# 	+ Label: person | Confidence: 0.9802
# 	+ Label: sports ball | Confidence: 0.5254
# Image data/samples/person.jpg:
# 	+ Label: person | Confidence: 0.9961
# 	+ Label: dog | Confidence: 0.9569
# Image data/samples/room.jpg:
# 	+ Label: chair | Confidence: 0.9887
# 	+ Label: chair | Confidence: 0.9126
# 	+ Label: clock | Confidence: 0.8306
# 	+ Label: chair | Confidence: 0.7362
# Image data/samples/street.jpg:
# 	+ Label: car | Confidence: 0.9997
# 	+ Label: car | Confidence: 0.9928
# 	+ Label: car | Confidence: 0.9913
# 	+ Label: car | Confidence: 0.9832
# 	+ Label: car | Confidence: 0.9791
# 	+ Label: car | Confidence: 0.9490
# 	+ Label: traffic light | Confidence: 0.9269
# 	+ Label: car | Confidence: 0.6887
# 	+ Label: car | Confidence: 0.6186
# 	+ Label: truck | Confidence: 0.5215
# 	+ Label: fire hydrant | Confidence: 0.5015
# ---- Detections were saved to: 'output' ----

# %%
ls -al /content/PyTorch-YOLOv3/data/samples/
# Out:
# total 1320
# drwxr-xr-x 2 root root   4096 Nov 24 12:36 ./
# drwxr-xr-x 4 root root   4096 Nov 24 12:36 ../
# -rw-r--r-- 1 root root 163759 Nov 24 12:36 dog.jpg
# -rw-r--r-- 1 root root 141886 Nov 24 12:36 eagle.jpg
# -rw-r--r-- 1 root root 113880 Nov 24 12:36 field.jpg
# -rw-r--r-- 1 root root 382965 Nov 24 12:36 giraffe.jpg
# -rw-r--r-- 1 root root 133495 Nov 24 12:36 herd_of_horses.jpg
# -rw-r--r-- 1 root root 126867 Nov 24 12:36 messi.jpg
# -rw-r--r-- 1 root root  78771 Nov 24 12:36 person.jpg
# -rw-r--r-- 1 root root  84988 Nov 24 12:36 room.jpg
# -rw-r--r-- 1 root root 102770 Nov 24 12:36 street.jpg

# %%
from IPython.display import Image
Image('/content/PyTorch-YOLOv3/data/samples/dog.jpg')

# %%
ls -al /content/PyTorch-YOLOv3/output/
# Out:
# total 2564
# drwxr-xr-x  2 root root   4096 Nov 24 10:32 ./
# drwxr-xr-x 10 root root   4096 Nov 24 10:32 ../
# -rw-r--r--  1 root root 326717 Nov 24 10:32 dog.png
# -rw-r--r--  1 root root 302837 Nov 24 10:32 eagle.png
# -rw-r--r--  1 root root 299712 Nov 24 10:32 field.png
# -rw-r--r--  1 root root 381156 Nov 24 10:32 giraffe.png
# -rw-r--r--  1 root root 267865 Nov 24 10:32 herd_of_horses.png
# -rw-r--r--  1 root root 242381 Nov 24 10:32 messi.png
# -rw-r--r--  1 root root 179369 Nov 24 10:32 person.png
# -rw-r--r--  1 root root 306767 Nov 24 10:32 room.png
# -rw-r--r--  1 root root 294388 Nov 24 10:32 street.png

# %%
Image('/content/PyTorch-YOLOv3/output/dog.png')
